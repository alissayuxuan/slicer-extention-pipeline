# %%
# %run Header_CreateModel_Mets.py C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\opensim_pipeline\base\setup\model_creation_base_setup.xml C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\opensim_pipeline\result\S03\setup\S03_pipeline_setup.xml
# Out:
# model_path =  C:/Users/hhuang10/Documents/Python/OpenSim-Spine-Project/opensim_pipeline\result\S03\models\S03_WHSMets.osim

# %%
# %run Header_CreateModel_Marker_CT.py C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\opensim_pipeline\base\setup\model_creation_base_setup.xml C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\opensim_pipeline\result\S03\setup\S03_pipeline_setup.xml
# Out:
# S03
# Marker data detected
# Adjusting Spine Curvature
# locking select joints
# Performing Scaling with:   Scale_setup_S03_SpineDistAdjust_Scaled
#
# unlocking select joints
# Making model with CCCs
# model_path =  C:/Users/hhuang10/Documents/Python/OpenSim-Spine-Project/opensim_pipeline\result\S03\models\S03_SpineDistAdjust_Scaled_unlock.osim
# ** Changing MTA max control to 5 **
# unlocking select joints
# Making models with different Box properties
# ------------------------------------------------------------------------------------

# %%
# %run Header_RunActivites.py C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\Pipeline\base\run_activities.xml C:\Users\hhuang10\Documents\Python\OpenSim-Spine-Project\Pipeline\patient_data\S03\patient.xml
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\hhuang10\AppData\Local\anaconda3\envs\osim\lib\site-packages\IPython\core\magics\execution.py:701, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     700     fpath = arg_lst[0]
# --> 701     filename = file_finder(fpath)
#     702 except IndexError as e:
#
# File c:\Users\hhuang10\AppData\Local\anaconda3\envs\osim\lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'Header_RunActivites.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ...
